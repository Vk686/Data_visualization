# %%
import numpy as np
import pandas as pd
import plotly as pl
import cufflinks as cf
import plotly.offline as po
# %matplotlib inline

# %%
po.init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.rand(100,5), columns = ['a','b','c','d','e'])

# %%
df.head()
# Out:
#           a         b         c         d         e
# 0  0.837981  0.092869  0.235384  0.131964  0.857359
# 1  0.859726  0.186183  0.221388  0.461856  0.701350
# 2  0.887507  0.339279  0.821474  0.106806  0.644324
# 3  0.713550  0.640033  0.011273  0.318816  0.422355
# 4  0.811279  0.730551  0.417130  0.632371  0.687409

# %%
df1 = pd.DataFrame({'x':['a','b','c','d','e'], 'y':[1,2,3,4,5,], 'z':[6,7,8,9,0]})

# %%
df1
# Out:
#    x  y  z
# 0  a  1  6
# 1  b  2  7
# 2  c  3  8
# 3  d  4  9
# 4  e  5  0

# %%
df.iplot(kind = 'scatter', x = 'a', y = 'b', mode = 'markers', size = 7)  #df.iplot(kind = 'scatter', x = 'a', y = 'b', mode = 'markers', size = 7) ,,,
# Out:
# <div>
#
#
#             <div id="ccad1d37-9260-486c-b6b0-677608adaa9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ccad1d37-9260-486c-b6b0-677608adaa9e")) {
#                     Plotly.newPlot(
#                         'ccad1d37-9260-486c-b6b0-677608adaa9e',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="d34b3d1d-7e16-4e55-b80c-c31d049dd8e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d34b3d1d-7e16-4e55-b80c-c31d049dd8e2")) {
#                     Plotly.newPlot(
#                         'd34b3d1d-7e16-4e55-b80c-c31d049dd8e2',
# ...
